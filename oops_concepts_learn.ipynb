# %% [markdown]
# # Object-Oriented Programming (OOP) in Python
#
# This notebook introduces OOP concepts step by step with practical examples. It is designed to help learners understand not just syntax, but also why these concepts are important in real-world programming.

# %% [markdown]
# ## 1. Why OOP matters

# %%
print("OOP helps us model real-world things like cars, students, banks, and employees using classes and objects.")

# %% [markdown]
# ## 2. Classes and Objects

# %%
class Student:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade

    def show_info(self):
        print(f"Name: {self.name}, Grade: {self.grade}")

s1 = Student("Asha", "A")
s2 = Student("Ravi", "B")

s1.show_info()
s2.show_info()
# Out:
# Name: Asha, Grade: A
# Name: Ravi, Grade: B

# %% [markdown]
# ## 3. The __init__ constructor

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

car1 = Car("Toyota", "Corolla")
print(car1.brand, car1.model)
# Out:
# Toyota Corolla

# %% [markdown]
# ## 4. Instance, class, and static methods

# %%
class Employee:
    company = "ABC Corp"

    def __init__(self, name):
        self.name = name

    def instance_method(self):
        print("This is an instance method")

    @classmethod
    def class_method(cls):
        print(f"Company: {cls.company}")

    @staticmethod
    def static_method():
        print("This is a static method")


e = Employee("Kiran")
e.instance_method()
Employee.class_method()
Employee.static_method()

# %% [markdown]
# ## 5. Inheritance: single inheritance

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

d = Dog()
d.speak()

# %% [markdown]
# ## 6. Inheritance: multiple inheritance

# %%
class A:
    def method_a(self):
        print("Method A")

class B:
    def method_b(self):
        print("Method B")

class C(A, B):
    pass

obj = C()
obj.method_a()
obj.method_b()

# %% [markdown]
# ## 7. Inheritance: multilevel inheritance

# %%
class Grandparent:
    def show(self):
        print("Grandparent")

class Parent(Grandparent):
    pass

class Child(Parent):
    pass

c = Child()
c.show()

# %% [markdown]
# ## 8. Polymorphism: method overriding

# %%
class Bird:
    def sound(self):
        print("Bird sound")

class Sparrow(Bird):
    def sound(self):
        print("Chirp")

for animal in [Bird(), Sparrow()]:
    animal.sound()

# %% [markdown]
# ## 9. Polymorphism: operator overloading

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

p1 = Point(1, 2)
p2 = Point(3, 4)
print(p1 + p2)

# %% [markdown]
# ## 10. Encapsulation: private and protected variables

# %%
class BankAccount:
    def __init__(self, balance):
        self._balance = balance
        self.__pin = 1234

    def show_balance(self):
        print(self._balance)

account = BankAccount(5000)
account.show_balance()
print("Protected variable accessed:", account._balance)

# %% [markdown]
# ## 13. Practice exercises

# %%
# Exercise 1: Create a class with a constructor and method
class Book:
    def __init__(self, title):
        self.title = title

    def show(self):
        print(self.title)

b = Book("Python OOP")
b.show()

# Exercise 2: Create a simple inheritance example
class Animal2:
    def speak(self):
        print("Sound")

class Cat(Animal2):
    def speak(self):
        print("Meow")

Cat().speak()
