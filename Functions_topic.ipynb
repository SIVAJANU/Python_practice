# %%
# in built functions in Python
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(100)
# Out:
# 10.0

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.ceil(9.6)
# Out:
# 10

# %%
math.floor(9.6)
# Out:
# 9

# %%
import datetime as dt
# get today's date and current datetime using previously imported datetime as dt
date_today = dt.date.today()
current_datetime = dt.datetime.now()

print("date_today =", date_today)
print("current_datetime =", current_datetime)
# Out:
# date_today = 2026-07-29
# current_datetime = 2026-07-29 22:32:03.052132

# %%
name=input("Entername")
greet_a_person=f'Hey...!! Mr. {name}, how are you..what is time now {current_datetime}'
print(greet_a_person)
# Out:
# Hey...!! Mr. Sudeep, how are you..what is time now 2026-07-29 22:32:03.052132

# %%
def greet(name):
    wish=f'Hi Mr.{name}..How are you'
    return  print(wish)

name_list=['Siva','Sivaram', 'Raviiiii']
L=len(name_list)
for i in range(L):
    greet(name_list[i])
# Out:
# Hi Mr.Siva..How are you
# Hi Mr.Sivaram..How are you
# Hi Mr.Raviiiii..How are you
